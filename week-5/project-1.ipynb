# %%
import csv
def load_data(GIGlogistics):
    mylist = []
    with open(GIGlogistics) as gig:
        gig_data = csv.reader(gig )
        next(gig_data) #skips the header
        for row in gig_data:
            mylist.append(row)
        return mylist
new_list = load_data('GIG-logistics.csv')
input1 = input("What is your  first name? ")
input2 = input("What is your  last name? ")
input3 = input("What department are you in?")
for row in new_list:
    print(row)
    fname = row[2] 
    lname = row[1]
    department = row[3]
    if input1 == fname and input2 == lname and input3 == department:
        print("Welcome",name)
    else:
        print("Sorry, that employee does not exist")

print("die")
# Out:
# What is your  first name?  h
# What is your  last name?  h
# What department are you in? n
# ['1', 'ADENIRAN', 'Oluwatamilore', 'Logistics']
# Sorry, that employee does not exist
# ['2', 'ADEWUMI', 'Ayomide', 'Accounting']
# Sorry, that employee does not exist
# ['3', 'ADOH-AJAGBE', 'Oshim', 'Delivery']
# Sorry, that employee does not exist
# ['4', 'AGBAKURU- NWOGU', 'Chukwunonye', 'Accounting']
# Sorry, that employee does not exist
# ['5', 'AGBAKWURU', 'Chiemeziem', 'Logistics']
# Sorry, that employee does not exist
# ['6', 'AKINDE', 'Oluwatimehin', 'Accounting']
# Sorry, that employee does not exist
# ['7', 'ARNIKA', 'Osose', 'Logistics']
# Sorry, that employee does not exist
# ['8', 'ATELLY', 'Daniel', 'Delivery']
# Sorry, that employee does not exist
# ['9', 'AZOGU', 'Onyekachi', 'Delivery']
# Sorry, that employee does not exist
# ['10', 'BETURE', 'Shalom', 'Delivery']
# Sorry, that employee does not exist
# ['11', 'CHUKWUMA', 'Nedi', 'Logistics']
# ...

# %%
import tkinter as tk

#GUI STEUP
#Create main window
root = tk.Tk()
root.title("GUI information checker")
root.geometry("700x700")

def welcomeMessage(name):
    #Create a Tkinter window
    window = tk.Toplevel(root)
    window.title("Department List")
    window.geometry("700x700")

    label_1 = tk.Label(window, text=f"Welcome {name}\n")
    label_1.pack()
    label_2 = tk.Label(window, text="This is GIG-logistics department login")
    label_2.pack()


    #Run the Tkinter event loop
    root.mainloop()

def submit():
    name = name_entry.get()
    department = department_entry.get()

    if name == "Mary" and department == "cos102":
        welcomeMessage(name)
    else:
        messagebox.showerror("Login", "Sorry, that employee does not exist")

#Create name Label and entry
name_label = tk.Label(root, text = "Name: ")
name_label.pack()
name_entry = tk.Entry(root)
name_entry.pack()

#Create department label and entry
department_label = tk.Label(root, text = "Department: ")
department_label.pack()
department_entry = tk.Entry(root)
department_entry.pack()

#Create submit button
submit_button = tk.Button(root, text="Submit", command=submit)
submit_button.pack()

#Run the main event Loop
root.mainloop()
