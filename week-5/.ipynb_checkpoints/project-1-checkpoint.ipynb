# %%
import tkinter as tk
from tkinter import messagebox

def submit():
    fulln = ["ADENIRAN Oluwatamilore","AGBAKWURU Chiemeziem","ARNIKA Osose","CHUKWUMA Nedi","EZEONYE Makuochukwu","GIWA	Moyosore","NWOKOLO Chijindu",
             "NWOTOKUBO Joseph","OKORO Derek","OSSAI Mary-Cynthia","PETER Owoede", "ADEWUMI Ayomide","AGBAKURU-NWOGU Chukwunonye","AKINDE Oluwatimehin",
             "EBI Stephanie","ICHA Ayonete","IKPATI Eche","OBASOGIE Daisy", "OBI Samuel","OBIALOR Betha","OLOWOKERE Akorede","OLUBUADE	Rasheed",
             "OSEMEKE Daniel","ADOH-AJAGBE Oshim","ATELLY	Daniel","AZOGU Onyekachi","BETURE Shalom","EJEDIMU Edward","ILOENYOSI ichael",
             "IYAWE Oluwadamilola", "OGBONNA Boluwatife","OIGBOCHIE	Mary","QUADRI Oluwafikunmi","UDE-IBE Uchenna", "EGBORO Jason","ELERI Otu",
             "EZE Onyinyechi","OKOCHA-OJEAH Raphael", "OKOLO Victor","UMEH Ejike"]


    dep = ["LOGISTICS","ACCOUNTING","DELIVERY","ADMINISTRATION"]

    logistics = ["ADENIRAN Oluwatamilore","AGBAKWURU Chiemeziem","ARNIKA Osose","CHUKWUMA Nedi","EZEONYE Makuochukwu","GIWA	Moyosore","NWOKOLO Chijindu",
                 "NWOTOKUBO Joseph","OKORO Derek","OSSAI Mary-Cynthia","PETER Owoede"]

    accounting =["ADEWUMI Ayomide","AGBAKURU-NWOGU Chukwunonye","AKINDE Oluwatimehin","EBI Stephanie","ICHA Ayonete","IKPATI Eche","OBASOGIE Daisy",
                 "OBI Samuel","OBIALOR Betha","OLOWOKERE Akorede","OLUBUADE	Rasheed","OSEMEKE Daniel"]

    delivery = ["ADOH-AJAGBE Oshim","ATELLY	Daniel","AZOGU Onyekachi","BETURE Shalom","EJEDIMU Edward","ILOENYOSI ichael","IYAWE Oluwadamilola",
                "OGBONNA Boluwatife","OIGBOCHIE	Mary","QUADRI Oluwafikunmi","UDE-IBE Uchenna"]

    administration = ["EGBORO Jason","ELERI	Otu","EZE Onyinyechi","OKOCHA-OJEAH	Raphael","OKOLO	Victor","UMEH Ejike"]


    fullname = fullname_entry.get()
    department = department_entry.get()

    if fullname in fulln and department in dep and department == "LOGISTICS":
        window2 = tk.Toplevel(root)
        listbox = tk.Listbox(window2,height = 20,width =150)
        window2.geometry("300x300")
        label = tk.Label(window2, text = "LOGISTICS")
        for i in logistics:
            listbox.insert(1,i)
        label.pack()
        listbox.pack()
    elif fullname in fulln and department in dep and department == "ACCOUNTING":
        window2 = tk.Toplevel(root)
        listbox = tk.Listbox(window2,height = 20,width =150)
        window2.geometry("300x300")
        label = tk.Label(window2, text = "ACCOUNTING")
        for i in accounting:
            listbox.insert(1,i)
        label.pack()
        listbox.pack()
    elif fullname in fulln and department in dep and department == "DELIVERY":
        window2 = tk.Toplevel(root)
        listbox = tk.Listbox(window2,height = 20,width =150)
        window2.geometry("300x300")
        label = tk.Label(window2, text = "DELIVERY")
        for i in delivery:
            listbox.insert(1,i)
        label.pack()
        listbox.pack()
    elif fullname in fulln and department in dep and department == "ADMINISTRATION":
        window2 = tk.Toplevel(root)
        listbox = tk.Listbox(window2,height = 20,width =150)
        window2.geometry("300x300")
        label = tk.Label(window2, text = "ADMINISTRATION")
        for i in administration:
            listbox.insert(1,i)
        label.pack()
        listbox.pack()
    else:
        messagebox.showerror("Login Error","This employee does not exist.Please check your login info and retry")

#Create main window
root = tk.Tk()
root.title("Employee Login")
root.geometry("1000x1000")

#Create label widjet
welcome_label = tk.Label(root, text="Welcome to GIG Logistics Employee Login \n")
welcome_label.pack()

#Create name Label and entry
fullname_label = tk.Label(root, text = "Fullame (Last name in capital letters and First name starting with a capital letter and Last name first): ")
fullname_label.pack()
fullname_entry = tk.Entry(root)
fullname_entry.pack()

#Create department label and entry
department_label = tk.Label(root, text = "Department(In capital letters): ")
department_label.pack()
department_entry = tk.Entry(root)
department_entry.pack()

#Create submit button
submit_button = tk.Button(root, text="Submit", command=submit)
submit_button.pack()

#Run the main event Loop
root.mainloop()
