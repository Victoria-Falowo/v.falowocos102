# %%
import tkinter as tk
from tkinter import messagebox
from tkinter import *

#Function for calculating price
def calc_order():
    name = name_entry.get()
    ricep1 = rice_pasta_entry.get()
    ricep = int(rice_pasta[ricep1])
    ricepquant = int(ricep_quantity_entry.get())
    sided1 = side_dishes_entry.get()
    sided = int(side_dishes[sided1])
    sidedquant = int(sided_quantity_entry.get())
    soupss1 = soups_swallows_entry.get()
    soupss = int(soups_swallows[soupss1])
    soupssquant = int(soupss_quantity_entry.get())
    bev1 = beverages_entry.get()
    bev = int(beverages[bev1])
    bevquant = int(beverages_quantity_entry.get())
    prot1 = proteins_entry.get()
    prot = int(proteins[prot1])
    protquant = int(proteins_quantity_entry.get())
  
    order = []
    total = 0
    totalr = 0
    totalsi = 0
    totalss = 0
    totalbev = 0
    totalprot = 0

    #Calculate the individual totals
    if ricep1 in rice_pasta:
        order.append(ricep1)
        totalr += (ricep * ricepquant)
    else:
        messagebox.showerror("Unavailable", "Sorry we aren't serving that dish today")

    if sided1 in side_dishes:
        order.append(sided1)
        totalsi += (sided * sidedquant)
    else:
        messagebox.showerror("Unavailable", "Sorry we aren't serving that dish today")

    if soupss1 in soups_swallows:
        order.append(soupss1)
        totalss += (soupss * soupssquant)
    else:
        messagebox.showerror("Unavailable", "Sorry we aren't serving that dish today")

    if bev1 in beverages:
        order.append(bev1)
        totalbev += (bev * bevquant)
    else:
        messagebox.showerror("Unavailable", "Sorry we aren't serving that dish today")

    if prot1 in proteins:
        order.append(prot1)
        totalprot += (prot * protquant)
    else:
        messagebox.showerror("Unavailable", "Sorry we aren't serving that dish today")

    #Apply discounts
    total = totalr + totalsi + totalss + totalbev + totalprot

    if total < 2500:
        total_2 = total * (10/100)
        print(f"Your total is N{total_2}")
        window = tk.Toplevel(menup)
        window.title("Price")
        window.geometry("500x200")

        label1= tk.Label(window, text = f"Thankyou for parionizing us, {name}")
        label1.pack()
        label2= tk.Label(window, text = f"Your final total is N{total_2}")
        label2.pack()
    elif total > 2500 and total < 5000:
        total_1 = total * (15/100)
        print(f"Your total is N{total_1}")
        window = tk.Toplevel(menup)
        window.title("Price")
        window.geometry("500x200")

        label1= tk.Label(window, text = f"Thankyou for parionizing us, {name}")
        label1.pack()
        label2= tk.Label(window, text = f"Your final total is N{total_1}")
        label2.pack()
    else:
        print(f"Your total is N{total}")
        window = tk.Toplevel(menup)
        window.title("Price")
        window.geometry("500x200")

        label1= tk.Label(window, text = f"Thankyou for parionizing us, {name}")
        label1.pack()
        label2= tk.Label(window, text = f"Your final total is N{total}")
        label2.pack()

    #Make New Window to display total
    window = tk.Toplevel(menup)
    window.title("Price")
    window.geometry("500x200")

    label1= tk.Label(window, text = f"Thankyou for parionizing us, {name}")
    label1.pack()
    label2= tk.Label(window, text = f"Your final total is N{total}")
    label2.pack()

#Cafeteria Menu
rice_pasta = {'Jollof Rice': 350,
              'Coconut Fried Rice': 350,
              'Jollof Spaghetti': 350,
              '': 0}
      
side_dishes = {"Beans": 350,
               "Roasted Sweet Potatoes": 300,
               "Fried Plantains": 150,
               "Mixed Vegetable Salad": 150,
               "Boiled Yam": 150,
               "": 0}

soups_swallows = {"Eba": 100,
                  "Poundo Yam": 100,
                  "Semo": 100,
                  "Acrra Soup": 450,
                  "Egusi Soup": 450,
                  "": 0}

proteins = {"Sweet Chil Chicken": 1100,
            "Grilled Chicken Wings": 400,
            "Fried Beef": 400,
            "Fried Fish": 500,
            "Boiled Egg": 200,
            "Sauteed Sausages": 200,
            "": 0}

beverages = {"Water": 200,
             "Glass Drinks (33cl)": 150,
             "PET Drink (35cl)": 300,
             "PET Drink (50cl)": 350,
             "Glass/Carried Malt": 500,
             "Fresh Yo": 600,
             "Pineapple Juice": 350,
             "Mango Juice": 350,
             "Zobo Drink": 350,
             "": 0}

#First window
menup = tk.Tk()
menup.title("PAU Cafeteria ")
menup.geometry("1000x1000")

#Create a welcome and rice and pasta label
welcome_label= tk.Label(menup,text = "Welcome to PAU Cafeteria")
welcome_label.pack()
rice_pasta_label1 = tk.Label(menup, text = "RICE/PASTA")
rice_pasta_label1.place(x = 150, y = 15)
rice_pasta_label2 = tk.Label(menup, text = "")
rice_pasta_label2["text"] = "\n".join(f"{key:30} N{value}".format(key, value) for (key, value) in rice_pasta.items())
rice_pasta_label2.place( x = 150, y =30)

#Create the side dishes menu
side_dishes1 = tk.Label(menup, text = "SIDE DISHES")
side_dishes1.place(x = 150, y = 85)
side_dishes2 = tk.Label(menup, text = "")
side_dishes2["text"] = "\n".join(f"{key:30} N{value}".format(key, value) for (key, value) in side_dishes.items())
side_dishes2.place( x = 150, y =100)

#Create the soups and swallows menu
soups_swallows1 = tk.Label(menup, text = "SOUPS AND SWALLOWS")
soups_swallows1.place(x = 150, y = 180)
soups_swallows2 = tk.Label(menup, text = "")
soups_swallows2["text"] = "\n".join(f"{key:30} N{value}".format(key, value) for (key, value) in soups_swallows.items())
soups_swallows2.place( x = 150, y =195)

#Create the protiens menu
proteins1 = tk.Label(menup, text = "PROTEINS")
proteins1.place(x = 150, y = 280)
proteins2 = tk.Label(menup, text = "")
proteins2["text"] = "\n".join(f"{key:30} N{value}".format(key, value) for (key, value) in proteins.items())
proteins2.place( x = 150, y =295)

#Create the protiens menu
beverages1 = tk.Label(menup, text = "BEVERAGES")
beverages1.place(x = 150, y = 400)
beverages2 = tk.Label(menup, text = "")
beverages2["text"] = "\n".join(f"{key:30} N{value}".format(key, value) for (key, value) in beverages.items())
beverages2.place( x = 150, y =415)

#Create name, order,  entry widget
name_label = tk.Label(menup, text = "Name:")
name_label.place(x = 650, y = 15)
name_entry = tk.Entry(menup)
name_entry.place(x = 700, y = 18)

rice_pasta_label = tk.Label(menup, text = "Rice/Pasta:")
rice_pasta_label.place(x = 650, y = 39)
rice_pasta_entry = tk.Entry(menup)
rice_pasta_entry.place(x = 720, y = 42)
ricep_quantity_label = tk.Label(menup, text ="Quantity:")
ricep_quantity_label.place(x = 650, y = 68)
ricep_quantity_entry = Spinbox(from_ =0, to = 10, width = 5)
ricep_quantity_entry.place(x = 720, y = 70)

side_dishes_label = tk.Label(menup, text = "Side Dishes:")
side_dishes_label.place(x = 650, y = 92)
side_dishes_entry = tk.Entry(menup)
side_dishes_entry.place(x = 720, y = 96)
sided_quantity_label = tk.Label(menup, text ="Quantity:")
sided_quantity_label.place(x = 650, y = 118)
sided_quantity_entry = Spinbox(from_ =0, to = 10 ,width = 5)
sided_quantity_entry.place(x = 720, y = 120)

soups_swallows_label = tk.Label(menup, text = "Soups and Swallows:")
soups_swallows_label.place(x = 650, y = 138)
soups_swallows_entry = tk.Entry(menup)
soups_swallows_entry.place(x = 770, y = 142)
soupss_quantity_label = tk.Label(menup, text ="Quantity:")
soupss_quantity_label.place(x = 650, y = 163)
soupss_quantity_entry = Spinbox(from_ =0, to = 10 ,width = 5)
soupss_quantity_entry.place(x = 720, y = 166)

beverages_label = tk.Label(menup, text = "Beverages:")
beverages_label.place(x = 650, y = 190)
beverages_entry = tk.Entry(menup)
beverages_entry.place(x = 720, y = 192)
beverages_quantity_label = tk.Label(menup, text ="Quantity:")
beverages_quantity_label.place(x = 650, y = 211)
beverages_quantity_entry = Spinbox(from_ =0, to = 10, width = 5)
beverages_quantity_entry.place(x = 720, y = 215)

proteins_label = tk.Label(menup, text = "Proteins:")
proteins_label.place(x = 650, y = 234)
proteins_entry = tk.Entry(menup)
proteins_entry.place(x = 720, y = 238)
proteins_quantity_label = tk.Label(menup, text ="Quantity:")
proteins_quantity_label.place(x = 650, y = 255)
proteins_quantity_entry = Spinbox(fro_ =0, to = 10, width = 5)
proteins_quantity_entry.place(x = 720, y = 260)

#Create submit button
submit_button = tk.Button(menup, text="Submit Order", command=calc_order)
submit_button.place(x = 755, y = 290)

#Run the main event loop
menup.mainloop()

#PSEUDOCODE
#1. Define dictionaries for different menu categories: 

#2. Define a function calc_order():
#    a. Retrieve user input from entry widgets for name and each menu category along with their quantities
#    b. Initialize variables for total order and individual category totals
#    c. Iterate over each menu category:
#        i. Check if the selected item exists in the corresponding dictionary
#        ii. If the item exists, calculate the subtotal for that category and update the total order
#        iii. If the item doesn't exist, display an error message
#    d. Apply discounts based on the total order value
#    e. Display the final total in a new window

#3. Create the main menu window:
#    a. Import the necessary modules
#    b. Define the layout and widgets for the main menu window:
#        i. Labels for menu categories and their respective items and prices
#        ii. Entry widgets for user input
#        iii. Submit button to calculate the order
#    c. Set up event handling for the submit button to call the calc_order() function
#    d. Run the main event loop to display the main menu window
